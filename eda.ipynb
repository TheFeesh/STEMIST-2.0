# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\user\Documents\GitHub\STEMIST-2.0\California_School_District_Areas_2022-23.csv")
data
# Out:
#      OBJECTID     Year   FedID   CDCode         CDSCode CountyName  \
# 0           1  2022-23  601770   161119   1611190000000    Alameda
# 1           2  2022-23  601860   161127   1611270000000    Alameda
# 2           3  2022-23  604740   161143   1611430000000    Alameda
# 3           4  2022-23  607800   161150   1611500000000    Alameda
# 4           5  2022-23  612630   161168   1611680000000    Alameda
# ..        ...      ...     ...      ...             ...        ...
# 934       938  2022-23  607260  5872728  58727280000000       Yuba
# 935       939  2022-23  624090  5872736  58727360000000       Yuba
# 936       940  2022-23  631180  5872744  58727440000000       Yuba
# 937       941  2022-23  642330  5872751  58727510000000       Yuba
# 938       942  2022-23  642350  5872769  58727690000000       Yuba
#
#                  DistrictName DistrictType GradeLow  GradeHigh  ... HOMpct  \
# 0             Alameda Unified      Unified       KG       12.0  ...    0.8
# ...

# %%
data.columns
# Out:
# Index(['OBJECTID', 'Year', 'FedID', 'CDCode', 'CDSCode', 'CountyName',
#        'DistrictName', 'DistrictType', 'GradeLow', 'GradeHigh',
#        'GradeLowCensus', 'GradeHighCensus', 'AssistStatus', 'CongressUS',
#        'SenateCA', 'AssemblyCA', 'LocaleDistrict', 'UpdateNotes',
#        'EnrollTotal', 'EnrollCharter', 'EnrollNonCharter', 'AAcount', 'AApct',
#        'AIcount', 'AIpct', 'AScount', 'ASpct', 'FIcount', 'FIpct', 'HIcount',
#        'HIpct', 'PIcount', 'PIpct', 'WHcount', 'WHpct', 'MRcount', 'MRpct',
#        'NRcount', 'NRpct', 'ELcount', 'ELpct', 'FOScount', 'FOSpct',
#        'HOMcount', 'HOMpct', 'MIGcount', 'MIGpct', 'SWDcount', 'SWDpct',
#        'SEDcount', 'SEDpct', 'DistrctAreaSqMi', 'Shape__Area',
#        'Shape__Length'],
#       dtype='object')

# %%
unnecessary_columns = ['OBJECTID', 'Year', 'FedID', 'CDCode', 'CDSCode','UpdateNotes', 'DistrictName', 'AssistStatus', 'CongressUS',
       'SenateCA', 'AssemblyCA']

# %%
data = data.drop(unnecessary_columns, axis=1)
data
# Out:
#     CountyName DistrictType GradeLow  GradeHigh GradeLowCensus  \
# 0      Alameda      Unified       KG       12.0             KG
# 1      Alameda      Unified       KG       12.0             KG
# 2      Alameda      Unified       KG       12.0             KG
# 3      Alameda      Unified       KG       12.0             KG
# 4      Alameda      Unified       KG       12.0             KG
# ..         ...          ...      ...        ...            ...
# 934       Yuba   Elementary       KG       12.0             KG
# 935       Yuba      Unified       KG       12.0             KG
# 936       Yuba   Elementary       KG        8.0             KG
# 937       Yuba   Elementary       KG        8.0             KG
# 938       Yuba         High       07       12.0             09
#
#      GradeHighCensus          LocaleDistrict  EnrollTotal  EnrollCharter  \
# 0                 12    21 - Suburban, Large        10359           1529
# ...

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# PIpct               1
# HOMpct              1
# ELpct               1
# FOScount            1
# FOSpct              1
# PIcount             1
# HIpct               1
# HIcount             1
# FIpct               1
# FIcount             1
# ASpct               1
# AScount             1
# HOMcount            1
# MIGcount            1
# MIGpct              1
# SWDcount            1
# SWDpct              1
# SEDcount            1
# SEDpct              1
# GradeHigh           1
# GradeLow            1
# NRcount             0
# DistrctAreaSqMi     0
# Shape__Area         0
# ELcount             0
# NRpct               0
# CountyName          0
# MRpct               0
# MRcount             0
# WHpct               0
# WHcount             0
# DistrictType        0
# AIpct               0
# AIcount             0
# AApct               0
# AAcount             0
# EnrollNonCharter    0
# EnrollCharter       0
# EnrollTotal         0
# LocaleDistrict      0
# GradeHighCensus     0
# ...

# %%
data.dropna(inplace=True)
data.isna().sum().sort_values(ascending=False)
# Out:
# CountyName          0
# HOMcount            0
# MRcount             0
# MRpct               0
# NRcount             0
# NRpct               0
# ELcount             0
# ELpct               0
# FOScount            0
# FOSpct              0
# HOMpct              0
# WHcount             0
# MIGcount            0
# MIGpct              0
# SWDcount            0
# SWDpct              0
# SEDcount            0
# SEDpct              0
# DistrctAreaSqMi     0
# Shape__Area         0
# WHpct               0
# PIpct               0
# DistrictType        0
# AAcount             0
# GradeLow            0
# GradeHigh           0
# GradeLowCensus      0
# GradeHighCensus     0
# LocaleDistrict      0
# EnrollTotal         0
# EnrollCharter       0
# EnrollNonCharter    0
# AApct               0
# PIcount             0
# AIcount             0
# AIpct               0
# AScount             0
# ASpct               0
# FIcount             0
# FIpct               0
# HIcount             0
# ...

# %%
data
# Out:
#     CountyName DistrictType GradeLow  GradeHigh GradeLowCensus  \
# 0      Alameda      Unified       KG       12.0             KG
# 1      Alameda      Unified       KG       12.0             KG
# 2      Alameda      Unified       KG       12.0             KG
# 3      Alameda      Unified       KG       12.0             KG
# 4      Alameda      Unified       KG       12.0             KG
# ..         ...          ...      ...        ...            ...
# 934       Yuba   Elementary       KG       12.0             KG
# 935       Yuba      Unified       KG       12.0             KG
# 936       Yuba   Elementary       KG        8.0             KG
# 937       Yuba   Elementary       KG        8.0             KG
# 938       Yuba         High       07       12.0             09
#
#      GradeHighCensus          LocaleDistrict  EnrollTotal  EnrollCharter  \
# 0                 12    21 - Suburban, Large        10359           1529
# ...

# %%
target = data['SEDpct']
print(target)
target = target > 50 
print(target)
# Out:
# 0      36.3
# 1      28.6
# 2      26.3
# 3      35.5
# 4      63.0
#        ...
# 934    53.4
# 935    74.3
# 936    37.4
# 937    48.8
# 938    80.6
# Name: SEDpct, Length: 938, dtype: float64
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 934     True
# 935     True
# 936    False
# 937    False
# 938     True
# Name: SEDpct, Length: 938, dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 938 entries, 0 to 938
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CountyName        938 non-null    object
#  1   DistrictType      938 non-null    object
#  2   GradeLow          938 non-null    object
#  3   GradeHigh         938 non-null    float64
#  4   GradeLowCensus    938 non-null    object
#  5   GradeHighCensus   938 non-null    int64
#  6   LocaleDistrict    938 non-null    object
#  7   EnrollTotal       938 non-null    int64
#  8   EnrollCharter     938 non-null    int64
#  9   EnrollNonCharter  938 non-null    int64
#  10  AAcount           938 non-null    int64
#  11  AApct             938 non-null    float64
#  12  AIcount           938 non-null    int64
#  13  AIpct             938 non-null    float64
#  14  AScount           938 non-null    float64
#  15  ASpct             938 non-null    float64
# ...

# %%
target
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 934     True
# 935     True
# 936    False
# 937    False
# 938     True
# Name: SEDpct, Length: 938, dtype: bool

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x=target)
for i in ax.containers:
    ax.bar_label(i,) 
plt.title('distribution')
plt.xlabel('status')
plt.ylabel('count')
plt.show()

# %%
for col in data.columns:
    print(f"{col}, {data[col].nunique()}")
# Out:
# CountyName, 58
# DistrictType, 3
# GradeLow, 6
# GradeHigh, 4
# GradeLowCensus, 4
# GradeHighCensus, 4
# LocaleDistrict, 12
# EnrollTotal, 852
# EnrollCharter, 268
# EnrollNonCharter, 830
# AAcount, 317
# AApct, 129
# AIcount, 134
# AIpct, 100
# AScount, 395
# ASpct, 212
# FIcount, 277
# FIpct, 89
# HIcount, 740
# HIpct, 577
# PIcount, 136
# PIpct, 32
# WHcount, 674
# WHpct, 565
# MRcount, 398
# MRpct, 162
# NRcount, 197
# NRpct, 85
# ELcount, 592
# ELpct, 396
# FOScount, 143
# FOSpct, 40
# HOMcount, 313
# HOMpct, 145
# MIGcount, 176
# MIGpct, 109
# SWDcount, 586
# SWDpct, 171
# SEDcount, 776
# SEDpct, 564
# DistrctAreaSqMi, 938
# Shape__Area, 938
# Shape__Length, 938

# %%
for col in data.columns:
    if data[col].dtype == 'object':
        print(col)
# Out:
# CountyName
# DistrictType
# GradeLow
# GradeLowCensus
# LocaleDistrict

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

code_key = {}

for col in data.columns:
    if data[col].dtype == 'object':
        data[col] = label_encoder.fit_transform(data[col])

        code_key[col] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# %%
print(data)
code_key
# Out:
#      CountyName  DistrictType  GradeLow  GradeHigh  GradeLowCensus  \
# 0             0             2         5       12.0               2
# 1             0             2         5       12.0               2
# 2             0             2         5       12.0               2
# 3             0             2         5       12.0               2
# 4             0             2         5       12.0               2
# ..          ...           ...       ...        ...             ...
# 934          57             0         5       12.0               2
# 935          57             2         5       12.0               2
# 936          57             0         5        8.0               2
# 937          57             0         5        8.0               2
# 938          57             1         2       12.0               1
#
#      GradeHighCensus  LocaleDistrict  EnrollTotal  EnrollCharter  \
# 0                 12               3        10359           1529
# ...

# %%
data.columns
# Out:
# Index(['CountyName', 'DistrictType', 'GradeLow', 'GradeHigh', 'GradeLowCensus',
#        'GradeHighCensus', 'LocaleDistrict', 'EnrollTotal', 'EnrollCharter',
#        'EnrollNonCharter', 'AAcount', 'AApct', 'AIcount', 'AIpct', 'AScount',
#        'ASpct', 'FIcount', 'FIpct', 'HIcount', 'HIpct', 'PIcount', 'PIpct',
#        'WHcount', 'WHpct', 'MRcount', 'MRpct', 'NRcount', 'NRpct', 'ELcount',
#        'ELpct', 'FOScount', 'FOSpct', 'HOMcount', 'HOMpct', 'MIGcount',
#        'MIGpct', 'SWDcount', 'SWDpct', 'SEDcount', 'SEDpct', 'DistrctAreaSqMi',
#        'Shape__Area', 'Shape__Length'],
#       dtype='object')

# %%
data[['CountyName', 'DistrictType', 'GradeLow', 'GradeHigh', 'GradeLowCensus',
       'GradeHighCensus', 'LocaleDistrict','EnrollTotal', 'EnrollCharter',
       'EnrollNonCharter', 'AAcount', 'AApct', 'AIcount', 'AIpct', 'AScount',
       'ASpct', 'FIcount', 'FIpct', 'HIcount', 'HIpct', 'PIcount', 'PIpct',
       'WHcount', 'WHpct', 'MRcount', 'MRpct', 'NRcount', 'NRpct', 'ELcount',
       'ELpct', 'FOScount', 'FOSpct', 'HOMcount', 'HOMpct', 'MIGcount',
       'MIGpct', 'SWDcount', 'SWDpct', 'SEDcount', 'SEDpct', 'DistrctAreaSqMi',
       'Shape__Area', 'Shape__Length']].hist(bins=100, figsize=(100,100))
# Out:
# array([[<Axes: title={'center': 'CountyName'}>,
#         <Axes: title={'center': 'DistrictType'}>,
#         <Axes: title={'center': 'GradeLow'}>,
#         <Axes: title={'center': 'GradeHigh'}>,
#         <Axes: title={'center': 'GradeLowCensus'}>,
#         <Axes: title={'center': 'GradeHighCensus'}>,
#         <Axes: title={'center': 'LocaleDistrict'}>],
#        [<Axes: title={'center': 'EnrollTotal'}>,
#         <Axes: title={'center': 'EnrollCharter'}>,
#         <Axes: title={'center': 'EnrollNonCharter'}>,
#         <Axes: title={'center': 'AAcount'}>,
#         <Axes: title={'center': 'AApct'}>,
#         <Axes: title={'center': 'AIcount'}>,
#         <Axes: title={'center': 'AIpct'}>],
#        [<Axes: title={'center': 'AScount'}>,
#         <Axes: title={'center': 'ASpct'}>,
#         <Axes: title={'center': 'FIcount'}>,
#         <Axes: title={'center': 'FIpct'}>,
#         <Axes: title={'center': 'HIcount'}>,
#         <Axes: title={'center': 'HIpct'}>,
# ...

# %%
code_key['DistrictType']
# Out:
# {'Elementary': 0, 'High': 1, 'Unified': 2}

# %% [markdown]
# ## Correlation Heatmaps

# %%
corr_matrix = data[['CountyName', 'DistrictType', 'GradeLow', 'GradeHigh', 'GradeLowCensus',
       'GradeHighCensus', 'LocaleDistrict']].corr()
sns.heatmap(corr_matrix)
plt.show()

# %%
corr_matrix = data[['AAcount', 'AApct', 'AIcount', 'AIpct', 'AScount',
       'ASpct', 'FIcount', 'FIpct', 'HIcount', 'HIpct', 'PIcount', 'PIpct',
       'WHcount', 'WHpct', 'MRcount', 'MRpct', 'NRcount', 'NRpct', 'ELcount',
       'ELpct', 'FOScount', 'FOSpct', 'HOMcount', 'HOMpct', 'MIGcount',
       'MIGpct', 'SWDcount', 'SWDpct', 'SEDcount', 'SEDpct']].corr()
sns.heatmap(corr_matrix)
plt.show()

# %%
plt.figure(figsize=(10,10))
corr_matrix = data[['CountyName', 'DistrictType', 'GradeLow', 'GradeHigh', 'GradeLowCensus',
       'GradeHighCensus', 'LocaleDistrict','EnrollTotal', 'EnrollCharter',
       'EnrollNonCharter',  'DistrctAreaSqMi',
       'Shape__Area', 'Shape__Length']].corr()
sns.heatmap(corr_matrix)
plt.show()
